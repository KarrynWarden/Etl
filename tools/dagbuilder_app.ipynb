# %% [markdown]
# # Конструктор ETL-дагов
#
# Две вкладки: **«Сложный ETL»** (свой даг на линию) и **«Справочники / разовый»** (регулярные справочники и разовый перенос — сборка, правка, включение/отключение таблиц). Заполняй форму и нажимай кнопки по порядку. Это веб-приложение: код и файлы репозитория отсюда не видны и не редактируются.

# %%
import os, sys
# найти корень репозитория (где лежит папка Functions) и добавить в путь
here = os.getcwd()
while here != '/' and not os.path.isdir(os.path.join(here, 'Functions')):
    here = os.path.dirname(here)
sys.path.insert(0, here)
from tools.dag_builder_ui import launch
launch()
