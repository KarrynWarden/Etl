# %% [markdown]
# # Генератор ETL-линии
#
# Запусти ячейку ниже — откроется **форма**. Все значения вводи в поля формы мышкой (не печатай в ячейки ноутбука).
#
# **Создать новый даг:** заполни таблицы, направление и пользователей БД → **1) Снять структуры из БД** → поправь сопоставление колонок и отметь первичный ключ (PK) → **2) Предпросмотр** → **3) Создать файлы**.
#
# **Редактировать существующий:** переключатель **✏️ Редактировать** → выбери линию → **Загрузить линию** → поменяй настройки/сопоставление → **3) Сохранить изменения**.
#
# Затем выкатить на тест: `sh deploy/deploy-test.sh "новая линия"`.
#
# > **Если форма не появилась** (видишь текст вроде `VBox(...)` или ошибку «model not found»): меню **Kernel → Restart Kernel and Clear All Outputs**, дождись перезапуска ядра и запусти ячейку снова.

# %%
import os, sys
# найти корень репозитория (где лежит папка Functions) и добавить в путь
here = os.getcwd()
while here != '/' and not os.path.isdir(os.path.join(here, 'Functions')):
    here = os.path.dirname(here)
sys.path.insert(0, here)
from tools.dag_builder_ui import launch
launch()
