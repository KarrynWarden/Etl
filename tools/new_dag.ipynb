# %% [markdown]
# # Генератор ETL-линии
# Запусти ячейку ниже — откроется форма. Порядок: заполнить таблицы и направление → **Снять структуры из БД** → поправить выпадашки сопоставления колонок → **Предпросмотр** → **Создать файлы**. Затем выкатить: `sh deploy/deploy-test.sh "новая линия"`.

# %%
import os, sys
# найти корень репозитория (где лежит папка Functions) и добавить в путь
here = os.getcwd()
while here != '/' and not os.path.isdir(os.path.join(here, 'Functions')):
    here = os.path.dirname(here)
sys.path.insert(0, here)
from tools.dag_builder_ui import launch
launch()
